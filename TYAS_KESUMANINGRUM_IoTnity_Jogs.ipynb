# %% [markdown]
# <a href="https://colab.research.google.com/github/lovvmg/mini-project-with-SIC/blob/main/TYAS_KESUMANINGRUM_IoTnity_Jogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
produk1 = "Kopi Pagi"
harga1 = 18000.5
produk2 = "Roti Cokelat"
harga2 = 10000
status_ketersediaan_roti = True

print("Nama Produk 1  :", produk1)
print("Harga Produk 1 :", harga1)
print("Nama Produk 2  :", produk2)
print("Harga Produk 2 :", harga2)
print("Status Ketersediaan Roti :", status_ketersediaan_roti)

#cara kedua
#print(f"\nNama Produk 1  :{produk1}\nHarga Produk 1 :{harga1}\nNama Produk 2  :{produk2}\nHarga Produk 2 :{produk2}\nStatus Ketersediaan Roti :{status_ketersediaan_roti}")

jumlah_pesanan_kopi = input("\nMasukkan jumlah pesanan kopi:")
jumlah_pesanan_roti = input("\nMasukkan jumlah pesanan roti:")
print(type(jumlah_pesanan_kopi))
print(type(jumlah_pesanan_roti))

jumlah_kopi_int = int(jumlah_pesanan_kopi)
jumlah_roti_int = int(jumlah_pesanan_roti)
print(type(jumlah_kopi_int) and type(jumlah_roti_int))

total_harga_kopi = harga1 * jumlah_kopi_int
total_harga_roti = harga2 * jumlah_roti_int
print("\ntotal harga kopi:",total_harga_kopi)
print("total harga roti:",total_harga_roti)

total_belanja = total_harga_kopi + total_harga_roti
print("total belanja keseluruhan :", total_belanja)

uang_yang_dibayarkan = 50000
print("uang uang dibayarkan :", uang_yang_dibayarkan)

kembalian = uang_yang_dibayarkan - total_belanja
print("kembalian :",kembalian)

nama_pelanggan = input("\nmasukkan nama anda: ")

print("*"*25)
pesan_terima_kasih = "Terima kasih " + nama_pelanggan + " sudah berbelanja di Coffee Shop Bahagia!"
print(pesan_terima_kasih)
print("*"*25)

print(f"total harga {produk1} adalah : {total_harga_kopi}")
# Out:
# Nama Produk 1  : Kopi Pagi
# Harga Produk 1 : 18000.5
# Nama Produk 2  : Roti Cokelat
# Harga Produk 2 : 10000
# Status Ketersediaan Roti : True
#
# Masukkan jumlah pesanan kopi:2
#
# Masukkan jumlah pesanan roti:3
# <class 'str'>
# <class 'str'>
# <class 'int'>
#
# total harga kopi: 36001.0
# total harga roti: 30000
# total belanja keseluruhan : 66001.0
# uang uang dibayarkan : 50000
# kembalian : -16001.0
#
# masukkan nama anda: hoshi
# *************************
# Terima kasih hoshi sudah berbelanja di Coffee Shop Bahagia!
# *************************
# total harga Kopi Pagi adalah : 36001.0
